# %% [markdown]
# # Assignment Operator

# %%
x=5
x+=3
x
# Out:
# 8

# %%
x=5
x=x+3
x
# Out:
# 8

# %%
x=5
x-=3
x
# Out:
# 2

# %%
x=5
x*=3
x
# Out:
# 15

# %%
x=5
x/=3
x
# Out:
# 1.6666666666666667

# %%
x=5
x%=3
x
#means=reminder
# Out:
# 2

# %%
x=5
x//=3
x
# Out:
# 1

# %%
x=5
x**=3
x
# Out:
# 125

# %% [markdown]
# # comparision operator

# %%
#gives output in true and false

# %%
x=9
y=6
x==y
# Out:
# False

# %%
x=9
y=9
x==y
# Out:
# True

# %%
x=9
y=6
x!=y
# Out:
# True

# %%
x=9
y=6
x>y
# Out:
# True

# %%
x=9
y=6
x<y
# Out:
# False

# %%
x=9
y=6
x>=y
#x is either grater or equal
# Out:
# True

# %%
x=9
y=6
x<=y
# Out:
# False
