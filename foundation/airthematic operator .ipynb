# %% [markdown]
# # Arithmetic operators

# %%
#AO are the mathematical operations

# %%
a=5
b=3
addition=a+b
addition
# Out:
# 8

# %%
subtraction =a-b
subtraction
# Out:
# 2

# %%
multiplication= a*b
multiplication
# Out:
# 15

# %%
devision = a/b
devision
# Out:
# 1.6666666666666667

# %%
floor_division_1=a//b
floor_division_1
# Out:
# 1

# %%
modulus=a%b
modulus
# reminder  of the division
# Out:
# 2

# %%
exponentiation=a**b
exponentiation
# Out:
# 125
