# %% [markdown]
# # logical operator

# %%
1. and 2. or. 3. not

# %%
print(True and True)
# Out:
# True

# %%
(True and True)
# Out:
# True

# %%
(True or False )
# Out:
# True

# %%
(True and False)
# Out:
# False

# %%
(not True)
# Out:
# False

# %%
(5>3) and (5<10)
# Out:
# True

# %%
(5>3) and (5>10)
# Out:
# False

# %%
(5>3) or (5>10)
# Out:
# True

# %%
(5>3) or (5<10)
# Out:
# True

# %%
(1<2 and 3<4 and 5<6)
# Out:
# True

# %%
(1<2 or 3<4) and (5<6)
# Out:
# True

# %%
(1<2 and  3>4) or (5>6)
# Out:
# False

# %%
(1<2 or 3<4) and  not (5==6)
# Out:
# False

# %%
(1<2 or 3<4) and  (5==6)
# Out:
# False

# %%
(3<5 and not 3>5 )
# Out:
# True

# %%
(3>2 and (1<2 or False))and not (2==2)
# Out:
# False

# %%
(3>2  or (1<2 or False))and not (2==2)
# Out:
# False

# %% [markdown]
# # Membership  Operator

# %%
(1 in [1,2,3])
# Out:
# True

# %%
(4 not in [1,2,3])
# Out:
# True

# %%
("a" in "cat")
# Out:
# True

# %%
("s" in "cat")
# Out:
# False

# %%
("key " in{"key",8800,"y46345"})
# Out:
# False

# %%
("distinct   " in "A paragraph is a distinct section othaning of the first sentence.")
# Out:
# False

# %%
("key" in{"key":1})
# Out:
# True

# %%
("key " in{"key ":1})
# Out:
# True

# %%
(5 in (5,6,7))
# Out:
# True

# %%
(10 not in [1,6,9])
# Out:
# True

# %% [markdown]
# # Identity Operator

# %%
# is , is not

# %%
x = y = [1,2,4]
x is y
# Out:
# True

# %%
z=[1,2,4]
(x is not z)
# Out:
# True

# %%
x=z=[1,2,4]
(x is not z)
# Out:
# False

# %%
x=z=[1,2,4]
(x is z)
# Out:
# True

# %%
("hello" is "hello")
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\hp\AppData\Local\Temp\ipykernel_9632\1569143145.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ("hello" is "hello")
# True

# %%
("hello" is "hillo")
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\hp\AppData\Local\Temp\ipykernel_9632\2150993636.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ("hello" is "hillo")
# False

# %%
a=[1,2,3]
b=[1,2,3]
# Out:
# True

# %%
obj1 =77
obj2=77

(obj1 == obj2 == 77)
(obj1 is obj2)
# Out:
# True

# %%
Bitwise operator
