# %%
a=67

# %%
a="hi"

print(a)
# Out:
# hi

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("shailja pandit")
# Out:
# shailja pandit

# %%
a=45

# %%
print(a)
# Out:
# 45

# %%
a=(45.7)
(a)
# Out:
# 45.7

# %%
b=("good evening")
print(b)
# Out:
# good evening

# %%
sh=("yoo")
print(sh)
# Out:
# yoo

# %%
#the above deals with the syntex errors

# %% [markdown]
# # first class of python

# %% [markdown]
# ## Data Type

# %%
9+8
# Out:
# 17

# %%
a=9 
b=6
c=a+b
print(c)
# Out:
# 15

# %%
a=12
b=10
c=a*b
print(c)
# Out:
# 120

# %%
a=14
b=9
c=a/b
print(c)
# Out:
# 1.5555555555555556

# %%
a=14
b=7
c=a//b
print(c)
# Out:
# 2

# %%
a=4
b=2
c=a**b
print(c)
# Out:
# 16

# %%
w=input("please enter your name ")
print (w)
# Out:
# please enter your name shailja
# shailja

# %%
a=[6,7,5]
a=banana

# %%
q=int(input("please enter your age"))
print(q)

# %%
a=87
